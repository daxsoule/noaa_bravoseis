# %% [markdown]
# # Review: lowband_0 (5,195 events, median 9.3 Hz)
#
# **Phase 3 lowband (1–14 Hz) gold standard review**
# Whale-filtered (catalogue peak_freq <= 14 Hz), UMAP+HDBSCAN min_cluster_size=200

# %%
from IPython.display import display, Image
from pathlib import Path

panel_dir = Path("../outputs/figures/exploratory/gold_standard")

# %%
for i in range(1, 16):
    p = panel_dir / f"gold_lowband_0_stratified_panel{i:02d}.png"
    if p.exists():
        print(f"--- Panel {i} ---")
        display(Image(filename=str(p), width=900))
# Out:
# --- Panel 1 ---
# --- Panel 2 ---
# --- Panel 3 ---
# --- Panel 4 ---
# --- Panel 5 ---
# --- Panel 6 ---
# --- Panel 7 ---
# --- Panel 8 ---
# --- Panel 9 ---
# --- Panel 10 ---
# --- Panel 11 ---
# --- Panel 12 ---
# --- Panel 13 ---
# --- Panel 14 ---
# --- Panel 15 ---

# %% [markdown]
# ## Review
#
# **Observations:**
# - Peak freq: 7.8–12.2 Hz — T-phase range
# - Duration: wide range, 3.4–28.2 s (median 6.0s) — longer than lowband_7
# - SNR: 3.5–21.4, median 8.7 — decent, broad range
# - Positive spectral slope (0.2–3.5) — energy increasing with frequency
# - Many panels show clear T-phase morphology: emergent onset, broadband 5–14 Hz, spindle envelope
# - Strong panels: 2, 8, 9, 10, 12, 13. Weaker: 4, 7, 11
# - All moorings represented, M6 slightly dominant, well-distributed
# - Big Feb 2019 peak (983 events), spread across year
# - Cruise check: 463 events during deployment, zero during shooting
#
# **Tracing from old clusters:** Old low_0 and low_1 (where user picked many clear earthquakes) → 417 events landed here, 2,571 in mega-cluster lowband_6. So the earthquake population is split between this cluster and the mega-cluster.
#
# **Verdict:** ACCEPT — T-phase / seismic. Second-tier confidence after lowband_7. Good source of additional training examples (especially high-SNR events like panels 9, 10, 12).
