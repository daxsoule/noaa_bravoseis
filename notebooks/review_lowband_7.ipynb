# %% [markdown]
# # Review: lowband_7 (645 events, median 11.7 Hz)
#
# **Phase 3 lowband (1–14 Hz) gold standard review**
# Whale-filtered (catalogue peak_freq <= 14 Hz), UMAP+HDBSCAN min_cluster_size=200

# %%
from IPython.display import display, Image
from pathlib import Path

panel_dir = Path("../outputs/figures/exploratory/gold_standard")

# %%
for i in range(1, 16):
    p = panel_dir / f"gold_lowband_7_stratified_panel{i:02d}.png"
    if p.exists():
        print(f"--- Panel {i} ---")
        display(Image(filename=str(p), width=900))
# Out:
# --- Panel 1 ---
# --- Panel 2 ---
# --- Panel 3 ---
# --- Panel 4 ---
# --- Panel 5 ---
# --- Panel 6 ---
# --- Panel 7 ---
# --- Panel 8 ---
# --- Panel 9 ---
# --- Panel 10 ---
# --- Panel 11 ---
# --- Panel 12 ---
# --- Panel 13 ---
# --- Panel 14 ---
# --- Panel 15 ---

# %% [markdown]
# ## Review
#
# **Observations:**
# - Peak freq: 9.3–13.7 Hz — solidly in T-phase range
# - Duration: 3.5–7.1 s
# - Good SNR: 4.3–22.4, median 11.4
# - Positive spectral slope: +1.1 to +2.9 — energy increases with frequency
# - Classic T-phase morphology: emergent onset, spindle-shaped envelope, gradual decay
# - Spectrograms show broadband energy concentrated at 8–14 Hz
# - Seasonal peak: Jul–Aug 2019 (austral winter)
# - Moorings: M4, M5, M6 dominant (southern/western array, near rift axis)
# - Cruise report check: only 2 events during cruise — clean
#
# **Fin whale check:** NEGATIVE
# - No regular IPI (only 3 intervals in 10–20s range out of hundreds)
# - Multi-mooring arrivals with propagation delays (seismic, not biological)
# - Seismic swarm behavior: Aug 21 had 50 events in 4 hours, irregular spacing
# - No periodicity — opposite of metronomic whale calling
#
# **Notable:** Aug 21 2019 swarm — 50 T-phases in 4 hours, M4-dominated, multi-mooring arrivals
#
# **Verdict:** ACCEPT — T-phase. Clean cluster of seismic T-phases with classic morphology.
