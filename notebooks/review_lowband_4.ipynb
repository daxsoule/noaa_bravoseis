# %% [markdown]
# # Review: lowband_4 (3,076 events, median 2.0 Hz)
#
# **Phase 3 lowband (1–14 Hz) gold standard review**
# Whale-filtered (catalogue peak_freq <= 14 Hz), UMAP+HDBSCAN min_cluster_size=200

# %%
from IPython.display import display, Image
from pathlib import Path

panel_dir = Path("../outputs/figures/exploratory/gold_standard")

# %%
for i in range(1, 16):
    p = panel_dir / f"gold_lowband_4_stratified_panel{i:02d}.png"
    if p.exists():
        print(f"--- Panel {i} ---")
        display(Image(filename=str(p), width=900))
# Out:
# --- Panel 1 ---
# --- Panel 2 ---
# --- Panel 3 ---
# --- Panel 4 ---
# --- Panel 5 ---
# --- Panel 6 ---
# --- Panel 7 ---
# --- Panel 8 ---
# --- Panel 9 ---
# --- Panel 10 ---
# --- Panel 11 ---
# --- Panel 12 ---
# --- Panel 13 ---
# --- Panel 14 ---
# --- Panel 15 ---

# %% [markdown]
# ## Review
#
# **Observations:**
# - Peak freq: 1.5–5.4 Hz, mostly 1.5–2.9 Hz
# - Very short duration: 1.1–2.6 s (median 1.9s — shortest cluster)
# - Low SNR: 3.0–4.5, all near detection threshold
# - Low amplitude, no coherent waveform morphology
# - Spectrograms show very brief transient blips — single time-frequency cell, no structure
# - M5 massively dominant (41%) — suggests mooring-specific noise or local sensitivity
# - Peak Jul 2019, Nov 2019, Jan 2020
# - Cruise check: 122 events during deployment, zero during shooting — not airgun
#
# **Verdict:** DISCARD. STA/LTA false triggers on ambient noise fluctuations. Very short duration, threshold-level SNR, no coherent waveform — not geologic signals.
