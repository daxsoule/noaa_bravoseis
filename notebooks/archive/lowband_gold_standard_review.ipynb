# %% [markdown]
# # Lowband (1–14 Hz) Gold Standard Review
#
# Phase 3 frequency-band reclassification. Reviewing clusters from `outputs/data/umap_coordinates_lowband.parquet`.
#
# **Band:** 1–14 Hz Butterworth bandpass (order 4)
# **Whale filter:** Removed events with catalogue peak_freq > 14 Hz (32,495 events = 38.4% were whale-contaminated)
# **Features:** `outputs/data/event_features_lowband.parquet` (52,175 events after filter)
# **Clusters:** 8 + noise, min_cluster_size=200, silhouette 0.083
# **Panels:** `outputs/figures/exploratory/gold_standard/gold_lowband_*_stratified_panel*.png`
# **UMAP:** `outputs/figures/exploratory/clustering/phase3_lowband/`
#
# | Cluster | Events | Median freq | Notes |
# |---------|--------|-------------|-------|
# | lowband_2 | 312 | 3.4 Hz | |
# | lowband_5 | 488 | 3.4 Hz | |
# | lowband_1 | 643 | 2.0 Hz | |
# | lowband_7 | 645 | 11.7 Hz | |
# | lowband_4 | 3,076 | 2.0 Hz | |
# | lowband_3 | 3,170 | 2.4 Hz | |
# | lowband_0 | 5,195 | 9.3 Hz | |
# | lowband_6 | 32,368 | 9.8 Hz | Mega-cluster |
# | lowband_noise | 6,278 | 5.4 Hz | |

# %%
from IPython.display import display, Image
from pathlib import Path

panel_dir = Path("../outputs/figures/exploratory/gold_standard")

# %% [markdown]
# ---
# ## Cluster lowband_2 (312 events, median 3.4 Hz)

# %%
for i in range(1, 16):
    p = panel_dir / f"gold_lowband_2_stratified_panel{i:02d}.png"
    if p.exists():
        print(f"--- Panel {i} ---")
        display(Image(filename=str(p), width=900))
# Out:
# --- Panel 1 ---
# --- Panel 2 ---
# --- Panel 3 ---
# --- Panel 4 ---
# --- Panel 5 ---
# --- Panel 6 ---
# --- Panel 7 ---
# --- Panel 8 ---
# --- Panel 9 ---
# --- Panel 10 ---
# --- Panel 11 ---
# --- Panel 12 ---
# --- Panel 13 ---
# --- Panel 14 ---
# --- Panel 15 ---

# %% [markdown]
# ### lowband_2 Review
#
# **Observations:**
# -
#
# **Verdict:**
