# %% [markdown]
# # Review: lowband_1 (643 events, median 2.0 Hz)
#
# **Phase 3 lowband (1–14 Hz) gold standard review**
# Whale-filtered (catalogue peak_freq <= 14 Hz), UMAP+HDBSCAN min_cluster_size=200

# %%
from IPython.display import display, Image
from pathlib import Path

panel_dir = Path("../outputs/figures/exploratory/gold_standard")

# %%
for i in range(1, 16):
    p = panel_dir / f"gold_lowband_1_stratified_panel{i:02d}.png"
    if p.exists():
        print(f"--- Panel {i} ---")
        display(Image(filename=str(p), width=900))
# Out:
# --- Panel 1 ---
# --- Panel 2 ---
# --- Panel 3 ---
# --- Panel 4 ---
# --- Panel 5 ---
# --- Panel 6 ---
# --- Panel 7 ---
# --- Panel 8 ---
# --- Panel 9 ---
# --- Panel 10 ---
# --- Panel 11 ---
# --- Panel 12 ---
# --- Panel 13 ---
# --- Panel 14 ---
# --- Panel 15 ---

# %% [markdown]
# ## Review
#
# **Observations:**
# - Peak freq: 1.5–4.4 Hz, bimodal — some at ~1.5–2.4 Hz, others at ~4.4 Hz
# - Short duration: 2.2–6.0 s
# - Low SNR: 3.0–6.4, mostly 3–5 — marginal detections
# - Low amplitude, impulsive onset with short coda (not tonal)
# - Spectrograms show transient broadband bursts concentrated below 5 Hz
# - Dates: spread across full deployment, peak Jun–Nov 2019 and Jan 2020
# - Moorings: well-distributed across all 6
# - Cruise report check: no survey artifact concern
#
# **Verdict:** DEFER. Possibly small local earthquakes or distant tectonic events, but low SNR and not representative of the primary T-phase / seismic population we're targeting. Come back to these after reviewing the larger, higher-frequency clusters.
